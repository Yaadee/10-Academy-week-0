# %%
import pandas as pd

# %%
import numpy as np

# %%
from IPython.display import display

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# #Loading csv data for statistical analysis and Eda

# %%
data_Benin_malanville = pd.read_csv("/home/yadasa/Desktop/10-Academy-week-0/src/models/datasets/Benin/solar-measurements_benin-malanville_qc.csv", encoding='latin-1',low_memory=False)

# %%
Converted_to_numeric = data_Benin_malanville.apply(pd.to_numeric, errors='coerce')

# %%
Converted_to_numeric.describe()
# Out:
#        Timestamp            GHI            DNI            DHI           ModA  \
# count        0.0  525600.000000  525600.000000  525600.000000  525600.000000
# mean         NaN     240.559452     167.187516     115.358961     236.589496
# std          NaN     331.131327     261.710501     158.691074     326.894859
# min          NaN     -12.900000      -7.800000     -12.600000       0.000000
# 25%          NaN      -2.000000      -0.500000      -2.100000       0.000000
# 50%          NaN       1.800000      -0.100000       1.600000       4.500000
# 75%          NaN     483.400000     314.200000     216.300000     463.700000
# max          NaN    1413.000000     952.300000     759.200000    1342.300000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      228.883576      28.179683      54.487969       2.121113
# std       316.536515       5.924297      28.073069       1.603466
# ...

# %%
null_counts = data_Benin_malanville[["GHI", "DNI", "DHI"]].isnull().sum()
print(null_counts)
# Out:
# GHI    0
# DNI    0
# DHI    0
# dtype: int64

# %%
# Select columns of interest and compute summary statistics
summary_statistics = data_Benin_malanville[['GHI', 'DNI', 'DHI']].describe()

# Print summary statistics
print("\nSummary Statistics:")
print(summary_statistics)
# Out:
# Summary Statistics:
#            GHI     DNI     DHI
# count   525601  525601  525601
# unique    8610    8906    6996
# top       -1.5    -0.3    -1.4
# freq     15339   47152   15025

# %%
# Find the column name(s) corresponding to the top values
top_values = {'GHI': -1.5, 'DNI': -0.3, 'DHI': -1.4}  # Assuming these are the top values in each column

for col, top_value in top_values.items():
    freq = summary_statistics.loc['freq', col]
    print(f"Column: {col}, Top Value: {top_value}, Frequency: {freq}")
# Out:
# Column: GHI, Top Value: -1.5, Frequency: 15339
# Column: DNI, Top Value: -0.3, Frequency: 47152
# Column: DHI, Top Value: -1.4, Frequency: 15025

# %%
# From tha output of the above we conclude that there is no missing value
# There is anomaly of error in the data bacuase normally the GHI, DNI and DHI should be positive

# %%
negative_values_count = (Converted_to_numeric[['GHI', 'DNI', 'DHI']] < 0).sum()
print("\nNegative Values Count:")
print(negative_values_count)
# Out:
# Negative Values Count:
# GHI    258847
# DNI    275987
# DHI    259182
# dtype: int64

# %%
plt.figure(figsize=(12, 8))

# %%
time_index = np.array(data_Benin_malanville.index)
print(data_Benin_malanville.columns)
# Out:
# Index(['Timestamp', 'GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'Tamb', 'RH', 'WS',
#        'WSgust', 'WSstdev', 'WD', 'WDstdev', 'BP', 'Cleaning', 'Precipitation',
#        'TModA', 'TModB', 'Comments'],
#       dtype='object')

# %%
# # Filter out rows with the placeholder string from the 'Timestamp' column
# data_Benin_malanville = data_Benin_malanville[data_Benin_malanville['Timestamp'] != 'yyyy-mm-dd hh:mm']
# data_Benin_malanville['Timestamp'] = pd.to_datetime(data_Benin_malanville['Timestamp'])

# # Plot the variables over time
# plt.figure(figsize=(12, 8))

# # Plot GHI
# plt.plot(data_Benin_malanville['Timestamp'].to_numpy(), data_Benin_malanville['GHI'].to_numpy(), label='GHI')

# # Plot DNI
# plt.plot(data_Benin_malanville['Timestamp'].to_numpy(), data_Benin_malanville['DNI'].to_numpy(), label='DNI')

# # Plot DHI
# plt.plot(data_Benin_malanville['Timestamp'].to_numpy(), data_Benin_malanville['DHI'].to_numpy(), label='DHI')

# # Plot Tamb
# plt.plot(data_Benin_malanville['Timestamp'].to_numpy(), data_Benin_malanville['Tamb'].to_numpy(), label='Tamb')

# # Add labels and title
# plt.xlabel('Timestamp')
# plt.ylabel('Value')
# plt.title('Variation of GHI, DNI, DHI, and Tamb over Time')
# plt.legend()
# plt.grid(True)

# # Show plot
# plt.show()

# %%
# Filter out rows with the placeholder string from the 'Timestamp' column
data_Benin_malanville = data_Benin_malanville[data_Benin_malanville['Timestamp'] != 'yyyy-mm-dd hh:mm']
data_Benin_malanville['Timestamp'] = pd.to_datetime(data_Benin_malanville['Timestamp'])

# Create subplots for each variable
fig, axs = plt.subplots(4, 1, figsize=(12, 10), sharex=True)

# Plot GHI
axs[0].plot(data_Benin_malanville['Timestamp'].to_numpy(), data_Benin_malanville['GHI'].to_numpy(), label='GHI', color='blue')
axs[0].set_ylabel('GHI')

# Plot DNI
axs[1].plot(data_Benin_malanville['Timestamp'].to_numpy(), data_Benin_malanville['DNI'].to_numpy(), label='DNI', color='green')
axs[1].set_ylabel('DNI')

# Plot DHI
axs[2].plot(data_Benin_malanville['Timestamp'].to_numpy(), data_Benin_malanville['DHI'].to_numpy(), label='DHI', color='red')
axs[2].set_ylabel('DHI')

# Plot Tamb
axs[3].plot(data_Benin_malanville['Timestamp'].to_numpy(), data_Benin_malanville['Tamb'].to_numpy(), label='Tamb', color='orange')
axs[3].set_ylabel('Tamb')

# Add common xlabel and title
plt.xlabel('Timestamp')
plt.suptitle('Variation of GHI, DNI, DHI, and Tamb over Time')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
# Plot GHI vs Tamb
plt.figure(figsize=(10, 6))
plt.scatter(data_Benin_malanville['Tamb'], data_Benin_malanville['GHI'], color='blue', label='GHI')
plt.xlabel('Ambient Temperature (Tamb)')
plt.ylabel('GHI (Global Horizontal Irradiance)')
plt.title('GHI vs Ambient Temperature')
plt.legend()
plt.grid(True)
plt.show()

# Plot DNI vs Tamb
plt.figure(figsize=(10, 6))
plt.scatter(data_Benin_malanville['Tamb'], data_Benin_malanville['DNI'], color='green', label='DNI')
plt.xlabel('Ambient Temperature (Tamb)')
plt.ylabel('DNI (Direct Normal Irradiance)')
plt.title('DNI vs Ambient Temperature')
plt.legend()
plt.grid(True)
plt.show()

# Plot DHI vs Tamb
plt.figure(figsize=(10, 6))
plt.scatter(data_Benin_malanville['Tamb'], data_Benin_malanville['DHI'], color='orange', label='DHI')
plt.xlabel('Ambient Temperature (Tamb)')
plt.ylabel('DHI (Diffuse Horizontal Irradiance)')
plt.title('DHI vs Ambient Temperature')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /home/yadasa/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yadasa/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(10, 6))

plt.scatter(data_Benin_malanville['Tamb'].to_numpy(), data_Benin_malanville['GHI'].to_numpy(), label='GHI', color='blue', marker='o', s=50)
plt.scatter(data_Benin_malanville['Tamb'].to_numpy(), data_Benin_malanville['DNI'].to_numpy(), label='DNI', color='green', marker='o', s=50)
plt.scatter(data_Benin_malanville['Tamb'].to_numpy(), data_Benin_malanville['DHI'].to_numpy(), label='DHI', color='orange', marker='o', s=50)

plt.xlabel('Ambient Temperature (Tamb)')
plt.ylabel('Irradiance')
plt.title('Variation of GHI, DNI, and DHI with Ambient Temperature')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %%
correlation_matrix = data_Benin_malanville[['GHI', 'DHI', 'DNI', 'TModA', 'TModB']].corr()
# Print correlation matrix
print("Correlation Matrix:")
correlation_matrix
# Out:
# Correlation Matrix:
#             GHI       DHI       DNI     TModA     TModB
# GHI    1.000000  0.849989  0.882376  0.920127  0.874338
# DHI    0.849989  1.000000  0.546602  0.825012  0.777829
# DNI    0.882376  0.546602  1.000000  0.790340  0.756007
# TModA  0.920127  0.825012  0.790340  1.000000  0.983443
# TModB  0.874338  0.777829  0.756007  0.983443  1.000000

# %%
# Convert DataFrame columns to numpy arrays
ws_data = data_Benin_malanville['WS'].to_numpy()
wsgust_data = data_Benin_malanville['WSgust'].to_numpy()
wsstdev_data = data_Benin_malanville['WSstdev'].to_numpy()
wd_data = data_Benin_malanville['WD'].to_numpy()
wdstdev_data = data_Benin_malanville['WDstdev'].to_numpy()

# Plot wind speed data
plt.figure(figsize=(12, 8))
plt.plot(data_Benin_malanville.index.to_numpy(), ws_data, label='WS')
plt.plot(data_Benin_malanville.index.to_numpy(), wsgust_data, label='WSgust')
plt.plot(data_Benin_malanville.index.to_numpy(), wsstdev_data, label='WSstdev')
plt.xlabel('Timestamp')
plt.ylabel('Wind Speed (m/s)')
plt.title('Wind Speed Trends')
plt.legend()
plt.grid(True)
plt.show()

# Plot wind direction data
plt.figure(figsize=(12, 8))
plt.plot(data_Benin_malanville.index.to_numpy(), wd_data, label='WD')
plt.plot(data_Benin_malanville.index.to_numpy(), wdstdev_data, label='WDstdev')
plt.xlabel('Timestamp')
plt.ylabel('Wind Direction (degrees)')
plt.title('Wind Direction Trends')
plt.legend()
plt.grid(True)
plt.show()



# Calculate summary statistics for wind speed
wind_speed_stats_summary = np.vstack((np.nanmin(ws_data),  # Min
                                      np.nanpercentile(ws_data, 25),  # 25th percentile
                                      np.nanmedian(ws_data),  # Median
                                      np.nanpercentile(ws_data, 75),  # 75th percentile
                                      np.nanmax(ws_data)))  # Max
print("Wind Speed Summary Statistics:")
print(wind_speed_stats_summary)

# Calculate summary statistics for wind gust speed
wind_gust_stats_summary = np.vstack((np.nanmin(wsgust_data),  # Min
                                     np.nanpercentile(wsgust_data, 25),  # 25th percentile
                                     np.nanmedian(wsgust_data),  # Median
                                     np.nanpercentile(wsgust_data, 75),  # 75th percentile
                                     np.nanmax(wsgust_data)))  # Max
print("\nWind Gust Speed Summary Statistics:")
print(wind_gust_stats_summary)

# Calculate summary statistics for wind speed standard deviation
wind_speed_stdev_stats_summary = np.vstack((np.nanmin(wsstdev_data),  # Min
                                            np.nanpercentile(wsstdev_data, 25),  # 25th percentile
                                            np.nanmedian(wsstdev_data),  # Median
                                            np.nanpercentile(wsstdev_data, 75),  # 75th percentile
                                            np.nanmax(wsstdev_data)))  # Max
print("\nWind Speed Standard Deviation Summary Statistics:")
print(wind_speed_stdev_stats_summary)

# Calculate summary statistics for wind direction
wind_direction_stats_summary = np.vstack((np.nanmin(wd_data),  # Min
                                          np.nanpercentile(wd_data, 25),  # 25th percentile
                                          np.nanmedian(wd_data),  # Median
                                          np.nanpercentile(wd_data, 75),  # 75th percentile
                                          np.nanmax(wd_data)))  # Max
print("\nWind Direction Summary Statistics:")
print(wind_direction_stats_summary)

# Calculate summary statistics for wind direction standard deviation
wind_direction_stdev_stats_summary = np.vstack((np.nanmin(wdstdev_data),  # Min
                                                np.nanpercentile(wdstdev_data, 25),  # 25th percentile
                                                np.nanmedian(wdstdev_data),  # Median
                                                np.nanpercentile(wdstdev_data, 75),  # 75th percentile
                                                np.nanmax(wdstdev_data)))  # Max
print("\nWind Direction Standard Deviation Summary Statistics:")
print(wind_direction_stdev_stats_summary)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[120], line 9
#       7 # Plot wind speed data
#       8 plt.figure(figsize=(12, 8))
# ----> 9 plt.plot(data_Benin_malanville.index.to_numpy(), ws_data, label='WS')
#      10 plt.plot(data_Benin_malanville.index.to_numpy(), wsgust_data, label='WSgust')
#      11 plt.plot(data_Benin_malanville.index.to_numpy(), wsstdev_data, label='WSstdev')
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
unique_values = data_Benin_malanville['Timestamp'].unique()
unique_values

# %%
# Calculate correlation matrix
correlation_matrix = data_Benin_malanville[['GHI', 'DHI', 'DNI', 'TModA', 'TModB']].corr()

# Print correlation matrix
print("Correlation Matrix:")
correlation_matrix

# %%
df=columns_to_describe.describe

# %%
display(df)

# %%
# data_Benin_parakou =pd.read_csv("/home/yadasa/Desktop/10-Academy-week-0/src/models/datasets/Benin/solar-measurements_benin-parakou_qc.csv",encoding='latin-1',low_memory=False)

# %%
data_SierraLeone_bumbuna=pd.read_csv("/home/yadasa/Desktop/10-Academy-week-0/src/models/datasets/Sirearra-Leone/solar-measurements_sierraleone-bumbuna_qc.csv" ,encoding='latin-1',low_memory=False)

# %%
# data_SierraLeone_kenema=pd.read_csv("/home/yadasa/Desktop/10-Academy-week-0/src/models/datasets/Sirearra-Leone/solar-measurements_sierraleone-kenema_qc.csv" ,encoding='latin-1',low_memory=False)

# %%
data_Togo_togodapaong = pd.read_csv("/home/yadasa/Desktop/10-Academy-week-0/src/models/datasets/Togo/solar-measurements_togo-dapaong_qc.csv" ,encoding='latin-1',low_memory=False)

# %%
# data_Togo_togodavie = pd.read_csv("/home/yadasa/Desktop/10-Academy-week-0/src/models/datasets/Togo/solar-measurements_togo-davie_qc.csv",encoding='latin-1',low_memory=False)

# %%
print("Summary Statistics for Benin Malanville Dataset:")
# Out:
# Summary Statistics for Benin Malanville Dataset:

# %%
print(data_Benin_malanville.describe())
# Out:
#        Comments
# count       0.0
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
print("\nSummary Statistics for Sierra Leone Bumbuna Dataset:")

# %%
print(data_SierraLeone_bumbuna.describe())

# %%
print("\nSummary Statistics for Sierra Leone Kenema Dataset:")

# %%
print(data_SierraLeone_kenema.describe())

# %%
print("\nSummary Statistics for Togo Dapaong Dataset:")

# %%
print(data_Togo_togodapaong.describe())
